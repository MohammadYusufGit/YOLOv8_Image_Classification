# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 898.8/898.8 kB 32.4 MB/s eta 0:00:00
# ...

# %%
# !yolo task=classify mode=train model=yolov8n-cls data=/content/drive/MyDrive/For_classification/dataset_2 epochs=100 imgsz=224
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100% 5.31M/5.31M [00:00<00:00, 154MB/s]
# Ultralytics 8.3.48 🚀 Python-3.10.12 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
# !yolo task=classify mode=val model=/content/runs/classify/train/weights/best.pt data=/content/drive/MyDrive/For_classification/dataset_2
# Out:
# Ultralytics 8.3.48 🚀 Python-3.10.12 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8n-cls summary (fused): 73 layers, 1,441,285 parameters, 0 gradients, 3.3 GFLOPs
# train: /content/drive/MyDrive/For_classification/dataset_2/train... found 175 images in 5 classes ✅
# val: /content/drive/MyDrive/For_classification/dataset_2/val... found 50 images in 5 classes ✅
# test: /content/drive/MyDrive/For_classification/dataset_2/test... found 25 images in 5 classes ✅
# val: Scanning /content/drive/MyDrive/For_classification/dataset_2/val... 50 images, 0 corrupt: 100% 50/50 [00:00<?, ?it/s]
#                classes   top1_acc   top5_acc: 100% 4/4 [00:02<00:00,  1.61it/s]
#                    all          1          1
# Speed: 0.0ms preprocess, 15.0ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to runs/classify/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# !yolo task=classify mode=predict model=/content/runs/classify/train/weights/best.pt source=/content/drive/MyDrive/For_classification/dataset_2/test
# Out:
# Ultralytics 8.3.48 🚀 Python-3.10.12 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8n-cls summary (fused): 73 layers, 1,441,285 parameters, 0 gradients, 3.3 GFLOPs
#
# image 1/25 /content/drive/MyDrive/For_classification/dataset_2/test/Airplane_14.jpg: 224x224 Airplane 1.00, motorcycle 0.00, Horse 0.00, car 0.00, Zebra 0.00, 36.6ms
# image 2/25 /content/drive/MyDrive/For_classification/dataset_2/test/Airplane_29.jpg: 224x224 Airplane 1.00, motorcycle 0.00, Horse 0.00, car 0.00, Zebra 0.00, 27.5ms
# image 3/25 /content/drive/MyDrive/For_classification/dataset_2/test/Airplane_4.jpg: 224x224 car 0.81, Airplane 0.17, Horse 0.01, motorcycle 0.00, Zebra 0.00, 16.6ms
# image 4/25 /content/drive/MyDrive/For_classification/dataset_2/test/Airplane_46.jpg: 224x224 Airplane 1.00, motorcycle 0.00, car 0.00, Horse 0.00, Zebra 0.00, 16.3ms
# ...
